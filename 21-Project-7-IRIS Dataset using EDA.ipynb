# %% [markdown]
# # IRIS DATASET VISUALIZATION(SEABORN,MATPLOTLIB)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
IRIS = pd.read_csv(r'D:\Data Science & AI class note\9th Dec\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv')
IRIS
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Displaying Data

# %%
IRIS.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
IRIS.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
IRIS.drop('Id',axis=1,inplace=True)

# %%
IRIS.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Checking if there are any missing values

# %%
IRIS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
IRIS['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# Bar Plot 
sns.countplot(x='Species',data=IRIS)
plt.show()

# %%
# Joint Plot
sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data = IRIS)
plt.show()

# %%
sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data = IRIS, kind='reg')
plt.show()

# %%
sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data = IRIS, kind='hex')
plt.show()

# %%
fg = sns.FacetGrid(IRIS, hue='Species')
fg.map(plt.scatter, 'SepalLengthCm','SepalWidthCm')
fg.add_legend()
plt.show()

# %%
IRIS.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxenplot(x='Species', y='PetalLengthCm', data=IRIS, order=['Iris-virginica','Iris-versicolor','Iris-setosa'], linewidth=2.5,orient='v',dodge=False)
plt.show()

# %%
IRIS.boxplot(by='Species', figsize=(12, 6))
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(10, 7)
fig = sns.stripplot(x='Species', y='SepalLengthCm', data=IRIS, jitter=True, edgecolor='gray', size=8, palette='winter', orient='v')
plt.show()

# %%
# Combining Box and Strip Plots
fig = plt.gcf()
fig.set_size_inches(10, 7)
fig = sns.boxplot(x='Species', y='SepalLengthCm', data=IRIS)
fig=sns.stripplot(x='Species', y='SepalLengthCm', data=IRIS, jitter=True, edgecolor='gray')
plt.show()

# %%
ax = sns.boxplot(x='Species', y='SepalLengthCm', data=IRIS)
ax = sns.stripplot(x='Species', y='SepalLengthCm', data=IRIS, jitter=True, edgecolor="gray")

if len(ax.artists) > 2:
    boxtwo = ax.artists[2]
    boxtwo.set_facecolor('yellow')
    boxtwo.set_edgecolor('black')
    
    boxthree = ax.artists[1]
    boxthree.set_facecolor('red')
    boxthree.set_edgecolor('black')
    
    boxone = ax.artists[0]
    boxone.set_facecolor('green')
    boxone.set_edgecolor('black')
plt.show()

# %%
# Violin plot
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.violinplot(x='Species', y='SepalLengthCm', data=IRIS)
plt.show()

# %%
IRIS.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.figure(figsize=(15, 10))
plt.subplot(2,2,1)
sns.violinplot(x='Species', y='PetalLengthCm', data=IRIS)
plt.title("petal Leangth")
plt.subplot(2,2,1)
sns.violinplot(x='Species', y='PetalWidthCm', data=IRIS)
plt.title("PetalWidthCm")
plt.subplot(2,2,1)
sns.violinplot(x='Species', y='SepalLengthCm', data=IRIS)
plt.title("SepalLengthCm")
plt.subplot(2,2,1)
sns.violinplot(x='Species', y='SepalWidthCm', data=IRIS)
plt.title("SepalWidthCm")
plt.tight_layout()
plt.show()

# %%
# Load the Iris dataset (adjust path or source as needed)
IRIS = sns.load_dataset('iris')  # If this fails, ensure it's correctly loaded

# %%
# Check column names
print(IRIS.columns)

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Subplot 1: Petal Length
sns.violinplot(ax=axes[0, 0], x='species', y='petal_length', data=IRIS)
axes[0, 0].set_title("Petal Length")

# Subplot 2: Petal Width
sns.violinplot(ax=axes[0, 1], x='species', y='petal_width', data=IRIS)
axes[0, 1].set_title("Petal Width")

# Subplot 3: Sepal Length
sns.violinplot(ax=axes[1, 0], x='species', y='sepal_length', data=IRIS)
axes[1, 0].set_title("Sepal Length")

# Subplot 4: Sepal Width
sns.violinplot(ax=axes[1, 1], x='species', y='sepal_width', data=IRIS)
axes[1, 1].set_title("Sepal Width")

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# pair plot
sns.pairplot(data=IRIS, kind='scatter')
plt.show()

# %%
sns.pairplot(IRIS, hue='species')
plt.show()

# %%
# Heat Map
plt.figure(figsize=(10, 7))  # Set the figure size
sns.heatmap(
    IRIS.corr(numeric_only=True), 
    annot=True, 
    cmap='cubehelix', 
    linewidths=1, 
    linecolor='k', 
    square=True, 
    vmin=-1, 
    vmax=1, 
    cbar_kws={"orientation": "vertical"}
)
plt.show()

# %%
# Distribution plot
IRIS.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)
plt.show()

# %%
sns.set(style='darkgrid')
fig=plt.gcf()
fig.set_size_inches(10,7)
fig = sns.swarmplot(x='species', y="petal_length", data=IRIS)
plt.show()

# %%
sns.set(style="whitegrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(x="species", y="petal_length", data=IRIS, inner=None)
ax = sns.swarmplot(x="species", y="petal_length", data=IRIS,color="white", edgecolor="black")
plt.show()

# %%
# LM plot
fig = sns.lmplot(x='petal_length', y='petal_width', data=IRIS)
plt.show()

# %%
# Face Grid
g = sns.FacetGrid(IRIS, hue='species', height=6)  # Use 'height' instead of 'size'
g.map(sns.kdeplot, "petal_length", fill=False)  # Add fill=True for filled KDE plots
g.add_legend()
plt.show()

# %%
IRIS.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
# Factor plot
sns.catplot(x="species", y="sepal_length", data=IRIS, kind="point")
plt.show()

# %%
# Boxen Plot
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxenplot(x="species", y="sepal_length", data=IRIS)
plt.show()

# %%
# KDE plot
sub = IRIS[IRIS['species'] == 'setosa']
sns.kdeplot(data=sub, x='sepal_length', y='sepal_width', cmap="plasma", shade=True, shade_lowest=False)
plt.title('IRIS-setosa')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.show()

# %%
#Dasboard

sns.set_style('darkgrid')
f, axes = plt.subplots(2,2, figsize=(15,15))

k1 = sns.boxenplot(x="species", y="petal_length", data=IRIS, ax=axes[0,0])
k2 = sns.violinplot(x="species", y="petal_length", data=IRIS, ax=axes[0,1])
k3 = sns.stripplot(
    x="species", 
    y="sepal_length", 
    data=IRIS, 
    jitter=True, 
    edgecolor='gray', 
    size=8, 
    palette='winter',  # Fixed typo: 'paletter' -> 'palette'
    orient='v', 
    ax=axes[1, 0]
)
axes[1, 1].hist(IRIS["petal_length"], bins=100, color='blue', edgecolor='black')
plt.show()

# %%
#Stacked Histogram
IRIS['species'] = IRIS['species'].astype('category')
list1 = list()
mylabels = list()
for gen in IRIS.species.cat.categories:
    list1.append(IRIS[IRIS.species==gen].sepal_length)
    mylabels.append(gen)
h = plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)
plt.legend()
plt.show()

# %%
# Area Plot
IRIS.plot.area(y=['sepal_length','sepal_width','petal_length','petal_width'], alpha = 0.4, figsize=(12,6))
plt.show()

# %%
#Distplot
sns.distplot(IRIS['sepal_length'], kde=True, bins=20)
plt.show()
